# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1          Buick Skylark 320  15.0        8.0         350.0       165.0
# 2         Plymouth Satellite  18.0        8.0         318.0       150.0
# 3              AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436           NaN     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
#undersampling
df.sample(n = 100)
# Out:
#                                       Car   MPG  Cylinders  Displacement  \
# 124                              Fiat 128  29.0        4.0          68.0
# 256     Oldsmobile Cutlass Salon Brougham  19.9        8.0         260.0
# 299  Chrysler Lebaron Town @ Country (sw)  18.5        8.0         360.0
# 168            Chevrolete Chevelle Malibu  16.0        6.0         250.0
# 188                      Honda Civic CVCC  33.0        4.0          91.0
# ..                                    ...   ...        ...           ...
# 119                            Ford Pinto  19.0        4.0         122.0
# 71                      Plymouth Fury III  15.0        8.0         318.0
# 356                           Mazda GLC 4  34.1        4.0          91.0
# 186                           Volvo 244DL  22.0        4.0         121.0
# 103               AMC Ambassador Brougham  13.0        8.0         360.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# ...

# %%
#sampling by fraction
df.sample(frac = 0.3)
# Out:
#                        Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 227  Datsun F-10 Hatchback  33.5        4.0          85.0        70.0    1945
# 208     Pontiac Ventura SJ  18.5        6.0         250.0       110.0    3645
# 313     Chevrolet Citation  28.8        6.0         173.0       115.0    2595
# 233          Buick Skylark  20.5        6.0         231.0       105.0    3425
# 111           Ford Country  12.0        8.0         400.0       167.0    4906
# ..                     ...   ...        ...           ...         ...     ...
# 138    Toyota Corolla 1200  32.0        4.0          71.0        65.0    1836
# 241  Pontiac Sunbird Coupe  24.5        4.0         151.0        88.0    2740
# 22              AMC Hornet  18.0        6.0         199.0         NaN    2774
# 364           Datsun 200SX  32.9        4.0         119.0       100.0    2615
# 268        AMC Concord d/l  18.1        6.0         258.0       120.0    3410
#
#      Acceleration  Model Origin
# ...

# %%
#oversampling
df.sample(n = 1000, replace=True)
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 154                   Fiat 128  24.0        4.0          90.0        75.0
# 221                  Ford F108  13.0        8.0         302.0       130.0
# 23               Ford Maverick  21.0        6.0         200.0        85.0
# 328             Toyota Corolla  32.2        4.0         108.0        75.0
# 156                Honda Civic  24.0        4.0         120.0        97.0
# ..                         ...   ...        ...           ...         ...
# 185                Peugeot 504  23.0        4.0         120.0        88.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 225              Renault 5 GTL  36.0        4.0          79.0        58.0
# 26                 Peugeot 504  25.0        4.0         110.0        87.0
# 314  Oldsmobile Omega Brougham  26.8        6.0         173.0       115.0
#
#      Weight  Acceleration  Model  Origin
# ...
