# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
#interquatile range
feature = 'Acceleration'

# %%
Q1 = df[feature].quantile(0.24)
Q3 = df[feature].quantile(0.23)

IQR = (Q3 - Q1) * 1.5
lower_bound = Q1-IQR
upper_bound = Q3 + IQR

print(f'Interquantile Range: {IQR}')
print(f'Lower Bound: {lower_bound}')
print(f'Upper Bound: {upper_bound}')
# Out:
# Interquantile Range: 0.0
# Lower Bound: 13.5
# Upper Bound: 13.5

# %%
#data without outliers
df.loc[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]
# Out:
#                             Car   MPG  Cylinders  Displacement  Horsepower  \
# 33                   Dodge D200  11.0        8.0         318.0       210.0
# 47             Ford Galaxie 500  14.0        8.0         351.0       153.0
# 52   AMC Hornet Sportabout (sw)  18.0        6.0         258.0       110.0
# 71            Plymouth Fury III  15.0        8.0         318.0       150.0
# 75         Buick LeSabre Custom  13.0        8.0         350.0       155.0
# 76   Oldsmobile Delta 88 Royale  12.0        8.0         350.0       160.0
# 78              Mazda RX2 Coupe  19.0        3.0          70.0        97.0
# 118                   Mazda RX3  18.0        3.0          70.0        90.0
# 130              Toyota Mark II  20.0        6.0         156.0       122.0
# 145   Dodge Coronet Custom (sw)  14.0        8.0         318.0       150.0
# 166                    Ford LTD  14.0        8.0         351.0       148.0
# ...

# %%
#outliers
df.loc[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# 5             Ford Galaxie 500  15.0        8.0         429.0       198.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...
