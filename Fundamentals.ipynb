# %%
'hi'
# Out:
# 'hi'

# %%
'hello'
# Out:
# 'hello'

# %%
#pandas Library
#!pip install pandas
#Excel Support Library (xlsx)
#!pip install openpyxl
#Excel Support Library (xls)
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
pd.Series([10,29,32,40])
# Out:
# 0    10
# 1    29
# 2    32
# 3    40
# dtype: int64

# %%
age=pd.Series([10,29,32,90])
age
# Out:
# 0    10
# 1    29
# 2    32
# 3    90
# dtype: int64

# %%
#Data Frames
apple = ['Apple', 60]
pineapple = ['pineapple', 70]
orange = ['orange', 30]

df=pd.DataFrame([apple,pineapple,orange])
df
# Out:
#            0   1
# 0      Apple  60
# 1  pineapple  70
# 2     orange  30

# %%
# Set Columns Names
df.columns =['Fruits','Price']
df
# Out:
#       Fruits  Price
# 0      Apple     60
# 1  pineapple     70
# 2     orange     30

# %%
#Series in Dictionary
pd.Series ({
    'Name':'janani',
    'age':19 })
# Out:
# Name    janani
# age         19
# dtype: object

# %%
#read and write
#write a dataframe to file
job1 = ['Design Engineer','2','LMW','Coimbatore']
job2 = ['Software Engineer','3','Milacron LLC','Bengaluru']
job3 = ['Lead Engineer','4','Shneilder Electric','Coimbatore']

experience = [job1,job2,job3]
df = pd.DataFrame(experience)
df.columns = ['Title','Years','Industry','Location']
df
# Out:
#                Title Years            Industry    Location
# 0    Design Engineer     2                 LMW  Coimbatore
# 1  Software Engineer     3        Milacron LLC   Bengaluru
# 2      Lead Engineer     4  Shneilder Electric  Coimbatore

# %%
df.to_csv('experience.csv', index=False)
df
# Out:
#                Title Years            Industry    Location
# 0    Design Engineer     2                 LMW  Coimbatore
# 1  Software Engineer     3        Milacron LLC   Bengaluru
# 2      Lead Engineer     4  Shneilder Electric  Coimbatore

# %%
#read a CSV File
df=pd.read_csv('3098329-data (1)/cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
df=pd.read_excel('3098329-data (1)/cars.xlsx')
df
# Out:
#                           cars Unnamed: 1 Unnamed: 2    Unnamed: 3  \
# 0                          Car        MPG  Cylinders  Displacement
# 1                       STRING     DOUBLE        INT        DOUBLE
# 2    Chevrolet Chevelle Malibu         18          8           307
# 3            Buick Skylark 320         15          8           350
# 4           Plymouth Satellite         18          8           318
# ..                         ...        ...        ...           ...
# 403            Ford Mustang GL         27          4           140
# 404          Volkswagen Pickup         44          4            97
# 405              Dodge Rampage         32          4           135
# 406                Ford Ranger         28          4           120
# 407                 Chevy S-10         31          4           119
#
#      Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0    Horsepower     Weight  Acceleration      Model     Origin
# ...

# %%
#adjusting the headers
df = pd.read_excel('3098329-data (1)/cars.xlsx', header=1)
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu      18         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
#read 2nd sheet
df=pd.read_excel('3098329-data (1)/cars.xlsx', sheet_name='Summary', header=1)
df
# Out:
#                  Car  MPG  Cylinders  Displacement  Horsepower  Weight  \
# 0         Ford Pinto   18          6           171          97    2984
# 1  Volkswagen Rabbit   29          4            90          70    1937
# 2          AMC Pacer   19          6           232          90    3211
# 3         Audi 100LS   23          4           115          95    2694
# 4        Peugeot 504   23          4           120          88    2957
# 5        Volvo 244DL   22          4           121          98    2945
# 6          Saab 99LE   25          4           121         115    2671
# 7   Honda Civic CVCC   33          4            91          53    1795
# 8           Fiat 131   28          4           107          86    2464
#
#    Acceleration  Model  Origin
# 0          14.5     75      US
# 1          14.0     75  Europe
# 2          17.0     75      US
# 3          15.0     75  Europe
# 4          17.0     75  Europe
# 5          14.5     75  Europe
# 6          13.5     75  Europe
# ...

# %%
#Basic operation
#import Library
import pandas as pd

# %%
#load dataset
df=pd.read_csv('3098329-data (1)/cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
#access individual columns and features
df['Car']
# Out:
# 0      Chevrolet Chevelle Malibu
# 1              Buick Skylark 320
# 2             Plymouth Satellite
# 3                  AMC Rebel SST
# 4                    Ford Torino
#                  ...
# 401              Ford Mustang GL
# 402            Volkswagen Pickup
# 403                Dodge Rampage
# 404                  Ford Ranger
# 405                   Chevy S-10
# Name: Car, Length: 406, dtype: object

# %%
#access multiple columns and features
df[['Car','Cylinders','Weight']]
# Out:
#                            Car  Cylinders  Weight
# 0    Chevrolet Chevelle Malibu        8.0    3504
# 1            Buick Skylark 320        8.0    3693
# 2           Plymouth Satellite        8.0    3436
# 3                AMC Rebel SST        8.0    3433
# 4                  Ford Torino        8.0    3449
# ..                         ...        ...     ...
# 401            Ford Mustang GL        4.0    2790
# 402          Volkswagen Pickup        4.0    2130
# 403              Dodge Rampage        4.0    2295
# 404                Ford Ranger        4.0    2625
# 405                 Chevy S-10        4.0    2720
#
# [406 rows x 3 columns]

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1          Buick Skylark 320  15.0        8.0         350.0       165.0
# 2         Plymouth Satellite  18.0        8.0         318.0       150.0
# 3              AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436           NaN     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
df.tail()
# Out:
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0        4.0         140.0        86.0    2790
# 402  Volkswagen Pickup  44.0        4.0          97.0        52.0    2130
# 403      Dodge Rampage  32.0        4.0         135.0        84.0    2295
# 404        Ford Ranger  28.0        4.0         120.0        79.0    2625
# 405         Chevy S-10  31.0        4.0         119.0        82.0    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     405 non-null    float64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    404 non-null    float64
#  5   Weight        406 non-null    int64
#  6   Acceleration  405 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 28.7+ KB

# %%
df.shape
# Out:
# (406, 9)

# %%
df.size
# Out:
# 3654

# %%
df.memory_usage(deep=True)
# Out:
# Index             128
# Car             29774
# MPG              3248
# Cylinders        3248
# Displacement     3248
# Horsepower       3248
# Weight           3248
# Acceleration     3248
# Model            3248
# Origin          24483
# dtype: int64
